# %%
import _referAsMain
import metrics.metrics as metrics
from pathlib import Path
# Out:
# added '/home/time/Bureau/pfe/PFE_LLM_art_generation' to import paths

# %%
errors = metrics.svg_is_fatal(Path("../../dataset/samples/0010_circle_packing.svg"))
print(errors)
# Out:
# False

# %%
errors = metrics.svg_is_fatal(Path("../0000_sketchy_lsys.svg"))
print(errors)
# Out:
# False

# %%
errors, warnings = metrics.svg_nb_errors(Path("../0000_sketchy_lsys.svg"))

print("Erreurs :", errors)
print("Warnings :", warnings)
# Out:
# Erreurs : 0
# Warnings : 0
