# %%
import _referAsMain
import random

from metrics import affichage, historique

# %%
historique = historique.Historique()
for i in range(100):
    historique.add_metric(metric_name="train", metric_value=i, epoch_id=i)
    historique.add_metric(metric_name="eval", metric_value=random.randint(0,100), epoch_id=i)
    historique.add_metric(metric_name="test", metric_value=5, epoch_id=i)

# %%
historique.add_commentaries(commentarie="coucou", epoch_id=1)
historique.add_commentaries(commentarie="ca va", epoch_id=1)
historique.add_commentaries(commentarie="salut", epoch_id=3)
historique.add_commentaries(commentarie="ouiiii", epoch_id=7)
historique.add_commentaries(commentarie="NONNNNNNNN", epoch_id= 45)
historique.add_commentaries(commentarie="et siiiii", epoch_id=82)

# %%
historique.get_all_metrics_name()
run_name = "test"

# %%
#n'executer cette cellule qu'une fois pour avoir id different a chaque test
actual_id = 0

# %%
affichage.affiche_metrics(historique, historique.get_all_metrics_name(), run_name + " " + str(actual_id))
actual_id += 1
# Out:
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/home/time/Bureau/pfe/PFE_LLM_art_generation/experiments/codes/wandb/run-20260308_004738-d4mlrhxo</code>
# Syncing run <strong><a href='https://wandb.ai/pfe_projet-organization/pfe/runs/d4mlrhxo' target="_blank">test 0</a></strong> to <a href='https://wandb.ai/pfe_projet-organization/pfe' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/pfe_projet-organization/pfe' target="_blank">https://wandb.ai/pfe_projet-organization/pfe</a>
#  View run at <a href='https://wandb.ai/pfe_projet-organization/pfe/runs/d4mlrhxo' target="_blank">https://wandb.ai/pfe_projet-organization/pfe/runs/d4mlrhxo</a>
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval</td><td>▇▄▃▃▄▆▇▅▇▅▅▃▁▁█▅▅█▅▇▆▆▂▇▄▁▂▂▅▅▅▃█▅▄▇▄█▁▆</td></tr><tr><td>test</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▅▅▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval</td><td>6</td></tr><tr><td>test</td><td>5</td></tr><tr><td>train</td><td>99</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">test 0</strong> at: <a href='https://wandb.ai/pfe_projet-organization/pfe/runs/d4mlrhxo' target="_blank">https://wandb.ai/pfe_projet-organization/pfe/runs/d4mlrhxo</a><br> View project at: <a href='https://wandb.ai/pfe_projet-organization/pfe' target="_blank">https://wandb.ai/pfe_projet-organization/pfe</a><br>Synced 5 W&B file(s), 1 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260308_004738-d4mlrhxo/logs</code>

# %%
run_name = "affichage historique"
actual_id = 0
affichage.affiche_commentaries(historique, run_name + " " + str(actual_id))
actual_id += 1
# Out:
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/home/time/Bureau/pfe/PFE_LLM_art_generation/experiments/codes/wandb/run-20260308_004744-56q3pq38</code>
# Syncing run <strong><a href='https://wandb.ai/pfe_projet-organization/pfe/runs/56q3pq38' target="_blank">affichage historique 0</a></strong> to <a href='https://wandb.ai/pfe_projet-organization/pfe' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/pfe_projet-organization/pfe' target="_blank">https://wandb.ai/pfe_projet-organization/pfe</a>
#  View run at <a href='https://wandb.ai/pfe_projet-organization/pfe/runs/56q3pq38' target="_blank">https://wandb.ai/pfe_projet-organization/pfe/runs/56q3pq38</a>
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval</td><td>▂▇▄▆▅▇▇▃▇▅▃▅▁▃▁▂▆█▅▃▆▃▄▂▅▄▆▅█▅▆▇▇█▂▆▆▂█▁</td></tr><tr><td>test</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train</td><td>▁▁▁▁▁▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇███</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval</td><td>6</td></tr><tr><td>test</td><td>5</td></tr><tr><td>train</td><td>99</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">affichage historique 0</strong> at: <a href='https://wandb.ai/pfe_projet-organization/pfe/runs/56q3pq38' target="_blank">https://wandb.ai/pfe_projet-organization/pfe/runs/56q3pq38</a><br> View project at: <a href='https://wandb.ai/pfe_projet-organization/pfe' target="_blank">https://wandb.ai/pfe_projet-organization/pfe</a><br>Synced 5 W&B file(s), 1 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260308_004744-56q3pq38/logs</code>
